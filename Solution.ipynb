# %%
from distribution import generate_h_m_h_y
from encrypt import F, ShiftRow, MixColumn
from util import read
from scipy.stats import binom, norm
from mle import m_y_mle
from main import peak_ids, analyze_MC_F

import numpy as np
import matplotlib.pyplot as plt

# %%
traces = read()
# Out:
# N: 10000
# L: 6100

# %%
roiL, roiR = 900, 1600
segL, segR = 1000, 1500
loc_m = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
roiL, roiR = 1500, 2500
segL, segR = 1600, 2340
loc_y = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
MK = analyze_MC_F(traces[:, loc_m], traces[:, loc_y])
bytes(MK)
# Out:
# mk 4B5243525950543232313032372D3238
# exp DDCDC6ECE7ED425E2651145BA7AF74AD
# ans DDCDC6ECE7ED425E2651145BA7AF74AD
# is_correct: True
# b'KRCRYPT221027-28'

# %%
roiL, roiR = 2300, 4000
segL, segR = 2400, 2920
loc_m = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
roiL, roiR = 2900, 4000
segL, segR = 3000, 3750
loc_y = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
MK = analyze_MC_F(traces[:, loc_m], traces[:, loc_y])
bytes(MK)
# Out:
# mk 4B5243525950543232313032372D3238
# exp DDCDC6ECE7ED425E2651145BA7AF74AD
# ans DDCDC6ECE7ED425E2651145BA7AF74AD
# is_correct: True
# b'KRCRYPT221027-28'

# %%
roiL, roiR = 3750, 5000
segL, segR = 3850, 4350
loc_m = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
roiL, roiR = 4300, 6000
segL, segR = 4450, 5200
loc_y = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
MK = analyze_MC_F(traces[:, loc_m], traces[:, loc_y])
bytes(MK)
# Out:
# mk 4B5243525950543232313032372D3238
# exp DDCDC6ECE7ED425E2651145BA7AF74AD
# ans DDCDC6ECE7ED425E2651145BA7AF74AD
# is_correct: True
# b'KRCRYPT221027-28'

# %%
roiL, roiR = 4300, 4500
segL, segR = 4350, 4450
loc_m = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
MK = analyze_MC_F(traces[:, loc_m], traces[:, loc_y])
bytes(MK)
# Out:
# mk 4B5243525950543232313032372D3258
# exp A8AED839E82E5C4EEF87E8EFB7014E33
# ans DDCDC6ECE7ED425E2651145BA7AF74AD
# is_correct: False
# b'KRCRYPT221027-2X'

# %%
roiL, roiR = 0, 500
segL, segR = 0, 160
loc_m = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
roiL, roiR = 1500, 2500
segL, segR = 1600, 2340
loc_y = slice(segL, segR)
sig = traces[:, segL:segR]
peaks = peak_ids(sig, 0.065)
plt.figure(figsize=(20,15))
plt.subplot(2, 1, 1)
plt.title('Average')
plt.plot(np.average(traces, axis=0)[roiL:roiR])
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.subplot(2, 1, 2)
plt.title('Variance')
plt.plot(np.std(traces, axis=0, ddof=1)[roiL:roiR], '-')
for i in peaks:
    plt.axvline((segL - roiL) + i, color='C1', linestyle='--')
plt.axvline(segL - roiL, color='r', linestyle='--')
plt.axvline(segR - roiL, color='r', linestyle='--')
plt.show()

# %%
MK = analyze_MC_F(traces[:, loc_m], traces[:, loc_y])
bytes(MK)
# Out:
# mk B1414E5E4E4EC15EB14EB16D4E4E4E5E
# exp 4AF8878F45343FAB17C4D36E3C38BD88
# ans DDCDC6ECE7ED425E2651145BA7AF74AD
# is_correct: False
# b'\xb1AN^NN\xc1^\xb1N\xb1mNNN^'
